# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95039fbd75c1> in <module>
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
! pip install requests
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests

# %%
res =requests.get('http://www.google.com')

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Date': 'Sun, 04 Aug 2019 06:06:10 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '5440', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2019-08-04-06; expires=Tue, 03-Sep-2019 06:06:10 GMT; path=/; domain=.google.com, NID=188=Pyo8veb27uz6QYap2axSnbnEBTCxs6iDhpq3vE9SdTWI5SlhGIBPNpYh6SwRfvHXpCvpDhM2B2XlNAfW8Zq2UBrt5phz7Q1W5neCOZonZFK2-2d0qcGKViTt_iAwr7Y7OEPirNVOXekSR1dM-VCwqdh_f2amXo6119mvxGdc9MU; expires=Mon, 03-Feb-2020 06:06:10 GMT; path=/; domain=.google.com; HttpOnly'}

# %%
res.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="xMh4D8hpIw1BvJpgWP/B5g==">(function(){window.google={kEI:\'0nVGXZC-JMj69QOlt7DIAQ\',kEXPI:\'0,201970,1151776,58,1957,2423,1225,730,224,510,245,820,3151,379,206,397,620,54,121,592,515,202,27,408,268,10,542,81,1133036,1197770,329498,1294,12383,4855,32692,15247,867,12163,6381,3335,2,2,6801,364,3319,5505,224,2215,5370,575,1119,2,578,728,2431,59,2,2,2,1297,4323,3698,1270,773,2255,1402,1413,1074,850,1146,9,8159,669,1050,1808,1478,7,3,488,2044,5762,1,3146,5297,897,1119,38,622,298,754,119,1217,1336,28,4347,48,1510,270,1233,2,215,1,415,3240,44,2374,2409,936,224,1207,252,620,2884,16,1,321,689,429,904,101,1049,975,1,368,1317,1461,519,400,472,520,97,1188,8,85,24,175,982,1356,174,889,78,48,553,11,14,10,1269,1286,
# ...

# %%
city='Delhi'
apiKey='53c63de66775fdf69a5b413bce7907d0'
baseUrl='http://api.openweathermap.org/data/2.5/weather'
url = f'{baseUrl}?q={city}&appid={apiKey}'
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?q=Delhi&appid=53c63de66775fdf69a5b413bce7907d0'

# %%
res=requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Server': 'openresty', 'Date': 'Sun, 04 Aug 2019 06:19:11 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '452', 'Connection': 'keep-alive', 'X-Cache-Key': '/data/2.5/weather?q=delhi', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST'}

# %%
res.content
# Out:
# b'{"coord":{"lon":77.22,"lat":28.65},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50d"}],"base":"stations","main":{"temp":304.43,"pressure":999,"humidity":75,"temp_min":303.15,"temp_max":305.15},"visibility":3000,"wind":{"speed":2.1,"deg":340},"clouds":{"all":75},"dt":1564899331,"sys":{"type":1,"id":9161,"message":0.0061,"country":"IN","sunrise":1564877630,"sunset":1564926038},"timezone":19800,"id":1273294,"name":"Delhi","cod":200}'

# %%
data=res.json()
data
# Out:
# {'coord': {'lon': 77.22, 'lat': 28.65},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 304.43,
#   'pressure': 999,
#   'humidity': 75,
#   'temp_min': 303.15,
#   'temp_max': 305.15},
#  'visibility': 3000,
#  'wind': {'speed': 2.1, 'deg': 340},
#  'clouds': {'all': 75},
#  'dt': 1564899331,
#  'sys': {'type': 1,
#   'id': 9161,
#   'message': 0.0061,
#   'country': 'IN',
#   'sunrise': 1564877630,
#   'sunset': 1564926038},
#  'timezone': 19800,
#  'id': 1273294,
#  'name': 'Delhi',
#  'cod': 200}

# %%
data['main']['temp_min']-273.15
# Out:
# 30.0

# %%
data['main']['temp_max']-273.15
# Out:
# 32.0

# %%
data['weather'][0]['description']
# Out:
# 'haze'

# %%
url= 'https://graph.facebook.com/4/picture?type=large'
res= requests.get(url)
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Last-Modified': 'Wed, 25 Jan 2017 10:54:37 GMT', 'x-haystack-needlechecksum': '3412181041', 'x-needle-checksum': '1664940563', 'Content-Type': 'image/jpeg', 'x-fb-config-version-olb-prod': '523', 'timing-allow-origin': '*', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'max-age=1209600, no-transform', 'x-enc-origin-req-handler': 'AcIJrSSqLeMfOjed8aTkRRtCMTtMrYWJ37bLRfXoP7NJ19DopbfnQEhMPCrABKRmo8y4U7kNehAzNWM1', 'X-FB-TRIP-ID': '389908146', 'Date': 'Sun, 04 Aug 2019 06:38:47 GMT', 'Access-Control-Expose-Headers': 'X-FB-CEC-Video-Limit', 'Connection': 'keep-alive', 'Content-Length': '8805'}

# %%
#res.content
# print only pixels vlues

# %%
with open('output/faceook.jpg','wb') as file:
    file.write(res.content)

# %% [markdown]
# ## Scrapping

# %%
! pip install html5lib
! pip install bs4
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
#   Running setup.py install for bs4: started
#     Running setup.py install for bs4: finished with status 'done'
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup

# %%
res =requests.get('http://www.flipkart.com')

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Server': 'nginx', 'Date': 'Sun, 04 Aug 2019 06:59:37 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Content-Security-Policy': "script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://sslwidget.criteo.com https://widget.as.criteo.com https://tnc.phonepe.com 'nonce-2334113328109987864'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://www.payzippy.com https://tnc.phonepe.com; font-src 'self' data: https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.ne
# ...

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.f34b67.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
soup=BeautifulSoup(res.content)

# %%
imgList =soup.findAll('img')
len(imgList)
# Out:
# 53

# %%
imgList[0]
# Out:
# <img alt="Flipkart" class="_1e_EAo" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png" title="Flipkart" width="75"/>

# %%
imgList[0]['class']
# Out:
# ['_1e_EAo']

# %%
[img.get('class') for img in imgList]
#get(class) so that some keys has o class thre give none
# Out:
# [['_1e_EAo'],
#  None,
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH'],
#  ['_2iEw0G'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1mkrTD'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
images =soup.findAll('img',attrs={'class':'_3I5S6S'})

# %%
images[0]['src']
# Out:
# 'https://rukminim1.flixcart.com/flap/50/50/image/9c06b9908141078e.jpg?q=50'

# %%
! pip install selenium
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
import time

# %%
path =r'C:\Users\This PC\Downloads\New folder\chromedriver.exe'
browser = webdriver.Chrome(path)

browser.get('https://www.google.com')
searchBox = browser.find_element_by_name('q')
searchBox.send_keys('India')

time.sleep(3)


searchBtn = browser.find_element_by_name('btnK')
searchBtn.click()

time.sleep(5)

wikiLink =browser.find_element_by_partial_link_text('Wikipedia')
wikiLink.click()
